# %% [markdown]
# # NumPy vs Py Analysis

# %%
from numpy_analysis import row_sums, dot_prod

# %%
matrix_sizes = [3, 4, 5, 6, 7, 8, 16, 32, 64]
_x = row_sums.run(matrix_sizes)
row_sums.save_to_csv(*_x,filename="benchmark_row_sums.csv")
fig = row_sums.plot(*_x)
fig.savefig("benchmark_row_sums.png")
# Out:
# Row Sums - Py (3x3)      : 0.04614 seconds
# Row Sums - NumPy (3x3)   : 0.24049 seconds
# 3x3 Matrix - Runtime difference: 0.19434 seconds
# 3x3 Matrix - Percentage difference: 421.18 %
#
# 3
# Row Sums - Py (4x4)      : 0.05113 seconds
# Row Sums - NumPy (4x4)   : 0.23722 seconds
# 4x4 Matrix - Runtime difference: 0.18608 seconds
# 4x4 Matrix - Percentage difference: 363.90 %
#
# 4
# Row Sums - Py (5x5)      : 0.06519 seconds
# Row Sums - NumPy (5x5)   : 0.24184 seconds
# 5x5 Matrix - Runtime difference: 0.17665 seconds
# 5x5 Matrix - Percentage difference: 270.98 %
#
# 5
# Row Sums - Py (6x6)      : 0.07786 seconds
# Row Sums - NumPy (6x6)   : 0.24533 seconds
# 6x6 Matrix - Runtime difference: 0.16747 seconds
# 6x6 Matrix - Percentage difference: 215.09 %
#
# 6
# Row Sums - Py (7x7)      : 0.08691 seconds
# Row Sums - NumPy (7x7)   : 0.24072 seconds
# 7x7 Matrix - Runtime difference: 0.15381 seconds
# 7x7 Matrix - Percentage difference: 176.98 %
#
# 7
# ...

# %%
[len(x) for x in _x]
# Out:
# [9, 9, 9, 9, 9]

# %%
matrix_sizes = [3, 4, 5, 6, 7, 8, 16, 32, 64,1000, 10000, 40000]
_x = dot_prod.run(matrix_sizes)
dot_prod.save_to_csv(*_x,filename="benchmark_dot_prod.csv")
fig = dot_prod.plot(*_x)
fig.savefig("benchmark_dot_prod.png")
# Out:
# Row Sums - Py (3x3)      : 0.09940 seconds
# Row Sums - NumPy (3)     : 0.16232 seconds
# 3 Matrix - Runtime difference: 0.06292 seconds
# 3 Matrix - Percentage difference: 63.30 %
#
# Row Sums - Py (4x4)      : 0.09788 seconds
# Row Sums - NumPy (4)     : 0.15822 seconds
# 4 Matrix - Runtime difference: 0.06034 seconds
# 4 Matrix - Percentage difference: 61.65 %
#
# Row Sums - Py (5x5)      : 0.09783 seconds
# Row Sums - NumPy (5)     : 0.15763 seconds
# 5 Matrix - Runtime difference: 0.05979 seconds
# 5 Matrix - Percentage difference: 61.12 %
#
# Row Sums - Py (6x6)      : 0.09953 seconds
# Row Sums - NumPy (6)     : 0.15687 seconds
# 6 Matrix - Runtime difference: 0.05735 seconds
# 6 Matrix - Percentage difference: 57.62 %
#
# Row Sums - Py (7x7)      : 0.09749 seconds
# Row Sums - NumPy (7)     : 0.15630 seconds
# 7 Matrix - Runtime difference: 0.05881 seconds
# 7 Matrix - Percentage difference: 60.33 %
#
# Row Sums - Py (8x8)      : 0.09954 seconds
# ...

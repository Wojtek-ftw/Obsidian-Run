# %% [markdown]
# # NumPy vs Py Analysis

# %%
from numpy_analysis import row_sums

# %%
matrix_sizes = [3, 4, 5, 6, 7, 8, 16, 32, 64]
_x = row_sums.run(matrix_sizes)
row_sums.save_to_csv(*_x,filename="benchmark_row_sums.csv")
fig = row_sums.plot(*_x)
fig.savefig("benchmark_row_sums.png")
# Out:
# Row Sums - Py (3x3)      : 0.04767 seconds
# Row Sums - NumPy (3x3)   : 0.24052 seconds
# 3x3 Matrix - Runtime difference: 0.19285 seconds
# 3x3 Matrix - Percentage difference: 404.53 %
#
# Row Sums - Py (4x4)      : 0.05137 seconds
# Row Sums - NumPy (4x4)   : 0.23343 seconds
# 4x4 Matrix - Runtime difference: 0.18206 seconds
# 4x4 Matrix - Percentage difference: 354.40 %
#
# Row Sums - Py (5x5)      : 0.06269 seconds
# Row Sums - NumPy (5x5)   : 0.24676 seconds
# 5x5 Matrix - Runtime difference: 0.18407 seconds
# 5x5 Matrix - Percentage difference: 293.62 %
#
# Row Sums - Py (6x6)      : 0.07595 seconds
# Row Sums - NumPy (6x6)   : 0.25045 seconds
# 6x6 Matrix - Runtime difference: 0.17450 seconds
# 6x6 Matrix - Percentage difference: 229.75 %
#
# Row Sums - Py (7x7)      : 0.09160 seconds
# Row Sums - NumPy (7x7)   : 0.24529 seconds
# 7x7 Matrix - Runtime difference: 0.15369 seconds
# 7x7 Matrix - Percentage difference: 167.78 %
#
# Row Sums - Py (8x8)      : 0.10326 seconds
# Row Sums - NumPy (8x8)   : 0.25219 seconds
# 8x8 Matrix - Runtime difference: 0.14893 seconds
# 8x8 Matrix - Percentage difference: 144.23 %
#
# Row Sums - Py (16x16)    : 0.25835 seconds
# Row Sums - NumPy (16x16) : 0.26693 seconds
# 16x16 Matrix - Runtime difference: 0.00857 seconds
# 16x16 Matrix - Percentage difference: 3.32 %
#
# Row Sums - Py (32x32)    : 0.76678 seconds
# Row Sums - NumPy (32x32) : 0.29542 seconds
# 32x32 Matrix - Runtime difference: -0.47137 seconds
# 32x32 Matrix - Percentage difference: -61.47 %
#
# Row Sums - Py (64x64)    : 2.45011 seconds
# Row Sums - NumPy (64x64) : 0.38037 seconds
# 64x64 Matrix - Runtime difference: -2.06974 seconds
# 64x64 Matrix - Percentage difference: -84.48 %
#
# Results saved to 'benchmark_row_sums.csv'.
